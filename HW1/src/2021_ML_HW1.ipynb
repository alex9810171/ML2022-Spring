# %% [markdown]
# # Homework 1: COVID-19 Cases Prediction (Regression)

# %% [markdown]
# # Download Data

# %%
# !nvidia-smi
# Out:
# Mon Feb 21 07:11:44 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
tr_path = 'covid.train.csv'  # path to training data
tt_path = 'covid.test.csv'   # path to testing data

# !gdown --id '19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF' --output covid.train.csv
# !gdown --id '1CE240jLm2npU-tdz81-oVKEF3T2yfT1O' --output covid.test.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF
# To: /content/covid.train.csv
# 100% 2.00M/2.00M [00:00<00:00, 166MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1CE240jLm2npU-tdz81-oVKEF3T2yfT1O
# To: /content/covid.test.csv
# 100% 651k/651k [00:00<00:00, 143MB/s]

# %% [markdown]
# # Import Some Packages

# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import csv
import os

# For plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

myseed = 42069  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %% [markdown]
# # Some Utilities

# %%
def get_device():
    ''' Get device (if GPU is available, use GPU) '''
    return 'cuda' if torch.cuda.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    ''' Plot learning curve of your DNN (train & dev loss) '''
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()


def plot_pred(dv_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dv_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('ground truth value')
    plt.ylabel('predicted value')
    plt.title('Ground Truth v.s. Prediction')
    plt.show()

# %% [markdown]
# # Preprocess

# %% [markdown]
# # Dataset

# %%
class COVID19Dataset(Dataset):
    ''' Dataset for loading and preprocessing the COVID19 dataset '''
    def __init__(self,
                 path,
                 mode='train',
                 target_only=False):
        self.mode = mode

        # Read data into numpy arrays
        with open(path, 'r') as fp:
            data = list(csv.reader(fp))
            data = np.array(data[1:])[:, 1:].astype(float)
        
        if not target_only:
            feats = list(range(93))
        else:
            # TODO: Using 40 states & 2 tested_positive features (indices = 57 & 75)
            pass

        if mode == 'test':
            # Testing data
            # data: 893 x 93 (40 states + day 1 (18) + day 2 (18) + day 3 (17))
            data = data[:, feats]
            self.data = torch.FloatTensor(data)
        else:
            # Training data (train/dev sets)
            # data: 2700 x 94 (40 states + day 1 (18) + day 2 (18) + day 3 (18))
            target = data[:, -1]
            data = data[:, feats]
            
            # Splitting training data into train & dev sets
            if mode == 'train':
                indices = [i for i in range(len(data)) if i % 10 != 0]
            elif mode == 'dev':
                indices = [i for i in range(len(data)) if i % 10 == 0]
            
            # Convert data into PyTorch tensors
            self.data = torch.FloatTensor(data[indices])
            self.target = torch.FloatTensor(target[indices])

        # Normalize features (you may remove this part to see what will happen)
        self.data[:, 40:] = \
            (self.data[:, 40:] - self.data[:, 40:].mean(dim=0, keepdim=True)) \
            / self.data[:, 40:].std(dim=0, keepdim=True)

        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

    def __getitem__(self, index):
        # Returns one sample at a time
        if self.mode in ['train', 'dev']:
            # For training
            return self.data[index], self.target[index]
        else:
            # For testing (no target)
            return self.data[index]

    def __len__(self):
        # Returns the size of the dataset
        return len(self.data)

# %% [markdown]
# # DataLoader

# %%
def prep_dataloader(path, mode, batch_size, n_jobs=0, target_only=False):
    ''' Generates a dataset, then is put into a dataloader. '''
    dataset = COVID19Dataset(path, mode=mode, target_only=target_only)  # Construct dataset
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)                            # Construct dataloader
    return dataloader

# %% [markdown]
# # Deep Neural Network

# %%
class NeuralNet(nn.Module):
    ''' A simple fully-connected deep neural network '''
    def __init__(self, input_dim):
        super(NeuralNet, self).__init__()

        # Define your neural network here
        # TODO: How to modify this model to achieve better performance?
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

        # Mean squared error loss
        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target):
        ''' Calculate loss '''
        # TODO: you may implement L1/L2 regularization here
        return self.criterion(pred, target)

# %% [markdown]
# # Training

# %%
def train(tr_set, dv_set, model, config, device):
    ''' DNN training '''

    n_epochs = config['n_epochs']  # Maximum number of epochs

    # Setup optimizer
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])
    print(optimizer)

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}      # for recording training loss
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()                           # set model to training mode
        for x, y in tr_set:                     # iterate through the dataloader
            optimizer.zero_grad()               # set gradient to zero
            x, y = x.to(device), y.to(device)   # move data to device (cpu/cuda)
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
            mse_loss.backward()                 # compute gradient (backpropagation)
            optimizer.step()                    # update model with optimizer
            loss_record['train'].append(mse_loss.detach().cpu().item())

        # After each epoch, test your model on the validation (development) set.
        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            # Save model if your model improved
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])  # Save model to specified path
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            # Stop training if your model stops improving for "config['early_stop']" epochs.
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %% [markdown]
# # Validation

# %%
def dev(dv_set, model, device):
    model.eval()                                # set model to evalutation mode
    total_loss = 0
    for x, y in dv_set:                         # iterate through the dataloader
        x, y = x.to(device), y.to(device)       # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
        total_loss += mse_loss.detach().cpu().item() * len(x)  # accumulate loss
    total_loss = total_loss / len(dv_set.dataset)              # compute averaged loss

    return total_loss

# %% [markdown]
# # Testing

# %%
def test(tt_set, model, device):
    model.eval()                                # set model to evalutation mode
    preds = []
    for x in tt_set:                            # iterate through the dataloader
        x = x.to(device)                        # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            preds.append(pred.detach().cpu())   # collect prediction
    preds = torch.cat(preds, dim=0).numpy()     # concatenate all predictions and convert to a numpy array
    return preds

# %% [markdown]
# # Setup Hyper-parameters

# %%
device = get_device()                 # get the current available device ('cpu' or 'cuda')
os.makedirs('models', exist_ok=True)  # The trained model will be saved to ./models/
target_only = False                   # TODO: Using 40 states & 2 tested_positive features

# TODO: How to tune these hyper-parameters to improve your model's performance?
config = {
    'n_epochs': 3000,                # maximum number of epochs
    'batch_size': 270,               # mini-batch size for dataloader
    'optimizer': 'Adam',              # optimization algorithm (optimizer in torch.optim)
    'optim_hparas': {                # hyper-parameters for the optimizer (depends on which optimizer you are using)
        'lr': 0.001,                 # learning rate of SGD
   ##     'momentum': 0.9              # momentum for SGD
    },
    'early_stop': 200,               # early stopping epochs (the number epochs since your model's last improvement)
    'save_path': 'models/model.pth'  # your model will be saved here
}

# %% [markdown]
# # Load data and model

# %%
tr_set = prep_dataloader(tr_path, 'train', config['batch_size'], target_only=target_only)
dv_set = prep_dataloader(tr_path, 'dev', config['batch_size'], target_only=target_only)
tt_set = prep_dataloader(tt_path, 'test', config['batch_size'], target_only=target_only)
# Out:
# Finished reading the train set of COVID19 Dataset (2430 samples found, each dim = 93)
# Finished reading the dev set of COVID19 Dataset (270 samples found, each dim = 93)
# Finished reading the test set of COVID19 Dataset (893 samples found, each dim = 93)

# %%
model = NeuralNet(tr_set.dataset.dim).to(device)  # Construct model and move to device

# %% [markdown]
# # Start Training!

# %%
model_loss, model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Saving model (epoch =    1, loss = 311.4044)
# Saving model (epoch =    2, loss = 294.0840)
# Saving model (epoch =    3, loss = 275.2820)
# Saving model (epoch =    4, loss = 253.8555)
# Saving model (epoch =    5, loss = 229.7336)
# Saving model (epoch =    6, loss = 203.4941)
# Saving model (epoch =    7, loss = 175.8891)
# Saving model (epoch =    8, loss = 147.9864)
# Saving model (epoch =    9, loss = 121.2206)
# Saving model (epoch =   10, loss = 96.8110)
# Saving model (epoch =   11, loss = 76.0997)
# Saving model (epoch =   12, loss = 59.9965)
# Saving model (epoch =   13, loss = 48.3793)
# Saving model (epoch =   14, loss = 40.8798)
# Saving model (epoch =   15, loss = 36.3868)
# Saving model (epoch =   16, loss = 33.7752)
# Saving model (epoch =   17, loss = 32.1509)
# Saving model (epoch =   18, loss = 30.9729)
# Saving model (epoch =   19, loss = 29.9639)
# Saving model (epoch =   20, loss = 29.0325)
# Saving model (epoch =   21, loss = 28.1245)
# Saving model (epoch =   22, loss = 27.2424)
# Saving model (epoch =   23, loss = 26.3955)
# Saving model (epoch =   24, loss = 25.5724)
# Saving model (epoch =   25, loss = 24.7427)
# Saving model (epoch =   26, loss = 23.9260)
# Saving model (epoch =   27, loss = 23.1069)
# Saving model (epoch =   28, loss = 22.3053)
# Saving model (epoch =   29, loss = 21.4891)
# Saving model (epoch =   30, loss = 20.6952)
# Saving model (epoch =   31, loss = 19.8831)
# Saving model (epoch =   32, loss = 19.0729)
# Saving model (epoch =   33, loss = 18.2443)
# Saving model (epoch =   34, loss = 17.4378)
# Saving model (epoch =   35, loss = 16.6556)
# Saving model (epoch =   36, loss = 15.8640)
# Saving model (epoch =   37, loss = 15.0467)
# Saving model (epoch =   38, loss = 14.2782)
# Saving model (epoch =   39, loss = 13.5340)
# Saving model (epoch =   40, loss = 12.8173)
# Saving model (epoch =   41, loss = 12.0898)
# Saving model (epoch =   42, loss = 11.4175)
# Saving model (epoch =   43, loss = 10.7714)
# Saving model (epoch =   44, loss = 10.1704)
# Saving model (epoch =   45, loss = 9.6235)
# Saving model (epoch =   46, loss = 9.0882)
# Saving model (epoch =   47, loss = 8.6108)
# Saving model (epoch =   48, loss = 8.1509)
# Saving model (epoch =   49, loss = 7.7347)
# Saving model (epoch =   50, loss = 7.3442)
# Saving model (epoch =   51, loss = 6.9952)
# Saving model (epoch =   52, loss = 6.6528)
# Saving model (epoch =   53, loss = 6.3479)
# Saving model (epoch =   54, loss = 6.0650)
# Saving model (epoch =   55, loss = 5.7839)
# Saving model (epoch =   56, loss = 5.5311)
# Saving model (epoch =   57, loss = 5.3199)
# Saving model (epoch =   58, loss = 5.0864)
# Saving model (epoch =   59, loss = 4.8913)
# Saving model (epoch =   60, loss = 4.7055)
# Saving model (epoch =   61, loss = 4.5398)
# Saving model (epoch =   62, loss = 4.3783)
# Saving model (epoch =   63, loss = 4.2419)
# Saving model (epoch =   64, loss = 4.1004)
# Saving model (epoch =   65, loss = 3.9772)
# Saving model (epoch =   66, loss = 3.8635)
# Saving model (epoch =   67, loss = 3.7662)
# Saving model (epoch =   68, loss = 3.6623)
# Saving model (epoch =   69, loss = 3.5689)
# Saving model (epoch =   70, loss = 3.4603)
# Saving model (epoch =   71, loss = 3.3904)
# Saving model (epoch =   72, loss = 3.3187)
# Saving model (epoch =   73, loss = 3.2295)
# Saving model (epoch =   74, loss = 3.1902)
# Saving model (epoch =   75, loss = 3.1053)
# Saving model (epoch =   76, loss = 3.0468)
# Saving model (epoch =   77, loss = 2.9816)
# Saving model (epoch =   78, loss = 2.9365)
# Saving model (epoch =   79, loss = 2.8716)
# Saving model (epoch =   80, loss = 2.8396)
# Saving model (epoch =   81, loss = 2.7771)
# Saving model (epoch =   82, loss = 2.7464)
# Saving model (epoch =   83, loss = 2.6903)
# Saving model (epoch =   84, loss = 2.6450)
# Saving model (epoch =   85, loss = 2.6099)
# Saving model (epoch =   86, loss = 2.5704)
# Saving model (epoch =   87, loss = 2.5445)
# Saving model (epoch =   88, loss = 2.4916)
# Saving model (epoch =   89, loss = 2.4709)
# Saving model (epoch =   90, loss = 2.4418)
# Saving model (epoch =   91, loss = 2.3864)
# Saving model (epoch =   92, loss = 2.3734)
# Saving model (epoch =   93, loss = 2.3423)
# Saving model (epoch =   94, loss = 2.3082)
# Saving model (epoch =   95, loss = 2.2860)
# Saving model (epoch =   96, loss = 2.2546)
# Saving model (epoch =   97, loss = 2.2330)
# Saving model (epoch =   98, loss = 2.2023)
# Saving model (epoch =   99, loss = 2.1852)
# Saving model (epoch =  100, loss = 2.1630)
# Saving model (epoch =  101, loss = 2.1426)
# Saving model (epoch =  102, loss = 2.1323)
# Saving model (epoch =  103, loss = 2.0978)
# Saving model (epoch =  104, loss = 2.0811)
# Saving model (epoch =  105, loss = 2.0766)
# Saving model (epoch =  106, loss = 2.0341)
# Saving model (epoch =  107, loss = 2.0259)
# Saving model (epoch =  108, loss = 2.0057)
# Saving model (epoch =  109, loss = 1.9918)
# Saving model (epoch =  110, loss = 1.9885)
# Saving model (epoch =  111, loss = 1.9400)
# Saving model (epoch =  112, loss = 1.9310)
# Saving model (epoch =  114, loss = 1.8930)
# Saving model (epoch =  115, loss = 1.8904)
# Saving model (epoch =  116, loss = 1.8644)
# Saving model (epoch =  117, loss = 1.8440)
# Saving model (epoch =  118, loss = 1.8392)
# Saving model (epoch =  119, loss = 1.8258)
# Saving model (epoch =  120, loss = 1.8037)
# Saving model (epoch =  122, loss = 1.7725)
# Saving model (epoch =  123, loss = 1.7657)
# Saving model (epoch =  124, loss = 1.7402)
# Saving model (epoch =  125, loss = 1.7278)
# Saving model (epoch =  126, loss = 1.7254)
# Saving model (epoch =  127, loss = 1.7015)
# Saving model (epoch =  128, loss = 1.6887)
# Saving model (epoch =  129, loss = 1.6795)
# Saving model (epoch =  130, loss = 1.6596)
# Saving model (epoch =  131, loss = 1.6584)
# Saving model (epoch =  132, loss = 1.6329)
# Saving model (epoch =  134, loss = 1.6119)
# Saving model (epoch =  135, loss = 1.6047)
# Saving model (epoch =  137, loss = 1.5874)
# Saving model (epoch =  138, loss = 1.5787)
# Saving model (epoch =  139, loss = 1.5563)
# Saving model (epoch =  141, loss = 1.5457)
# Saving model (epoch =  143, loss = 1.5350)
# Saving model (epoch =  144, loss = 1.5231)
# Saving model (epoch =  145, loss = 1.5159)
# Saving model (epoch =  146, loss = 1.5125)
# Saving model (epoch =  147, loss = 1.4949)
# Saving model (epoch =  148, loss = 1.4932)
# Saving model (epoch =  149, loss = 1.4880)
# Saving model (epoch =  150, loss = 1.4850)
# Saving model (epoch =  151, loss = 1.4724)
# Saving model (epoch =  152, loss = 1.4674)
# Saving model (epoch =  153, loss = 1.4594)
# Saving model (epoch =  155, loss = 1.4393)
# Saving model (epoch =  157, loss = 1.4366)
# Saving model (epoch =  158, loss = 1.4239)
# Saving model (epoch =  159, loss = 1.4202)
# Saving model (epoch =  160, loss = 1.4117)
# Saving model (epoch =  161, loss = 1.4112)
# Saving model (epoch =  162, loss = 1.4008)
# Saving model (epoch =  163, loss = 1.3945)
# Saving model (epoch =  164, loss = 1.3872)
# Saving model (epoch =  165, loss = 1.3862)
# Saving model (epoch =  166, loss = 1.3731)
# Saving model (epoch =  168, loss = 1.3628)
# Saving model (epoch =  171, loss = 1.3409)
# Saving model (epoch =  175, loss = 1.3309)
# Saving model (epoch =  176, loss = 1.3246)
# Saving model (epoch =  178, loss = 1.3168)
# Saving model (epoch =  179, loss = 1.3166)
# Saving model (epoch =  180, loss = 1.2986)
# Saving model (epoch =  182, loss = 1.2902)
# Saving model (epoch =  184, loss = 1.2721)
# Saving model (epoch =  188, loss = 1.2586)
# Saving model (epoch =  190, loss = 1.2548)
# Saving model (epoch =  193, loss = 1.2523)
# Saving model (epoch =  194, loss = 1.2438)
# Saving model (epoch =  196, loss = 1.2352)
# Saving model (epoch =  198, loss = 1.2344)
# Saving model (epoch =  199, loss = 1.2293)
# Saving model (epoch =  200, loss = 1.2202)
# Saving model (epoch =  202, loss = 1.2024)
# Saving model (epoch =  206, loss = 1.1998)
# Saving model (epoch =  208, loss = 1.1977)
# Saving model (epoch =  209, loss = 1.1849)
# Saving model (epoch =  211, loss = 1.1687)
# Saving model (epoch =  219, loss = 1.1657)
# Saving model (epoch =  220, loss = 1.1619)
# Saving model (epoch =  221, loss = 1.1598)
# Saving model (epoch =  222, loss = 1.1525)
# Saving model (epoch =  225, loss = 1.1477)
# Saving model (epoch =  226, loss = 1.1423)
# Saving model (epoch =  227, loss = 1.1410)
# Saving model (epoch =  229, loss = 1.1399)
# Saving model (epoch =  230, loss = 1.1233)
# Saving model (epoch =  233, loss = 1.1210)
# Saving model (epoch =  235, loss = 1.1089)
# Saving model (epoch =  238, loss = 1.0969)
# Saving model (epoch =  241, loss = 1.0915)
# Saving model (epoch =  247, loss = 1.0747)
# Saving model (epoch =  252, loss = 1.0724)
# Saving model (epoch =  254, loss = 1.0642)
# Saving model (epoch =  258, loss = 1.0561)
# Saving model (epoch =  262, loss = 1.0499)
# Saving model (epoch =  264, loss = 1.0497)
# Saving model (epoch =  265, loss = 1.0318)
# Saving model (epoch =  270, loss = 1.0229)
# Saving model (epoch =  273, loss = 1.0207)
# Saving model (epoch =  275, loss = 1.0193)
# Saving model (epoch =  278, loss = 1.0066)
# Saving model (epoch =  280, loss = 1.0048)
# Saving model (epoch =  283, loss = 1.0027)
# Saving model (epoch =  285, loss = 1.0013)
# Saving model (epoch =  287, loss = 0.9986)
# Saving model (epoch =  289, loss = 0.9880)
# Saving model (epoch =  294, loss = 0.9855)
# Saving model (epoch =  296, loss = 0.9842)
# Saving model (epoch =  297, loss = 0.9725)
# Saving model (epoch =  300, loss = 0.9668)
# Saving model (epoch =  301, loss = 0.9617)
# Saving model (epoch =  303, loss = 0.9602)
# Saving model (epoch =  310, loss = 0.9481)
# Saving model (epoch =  318, loss = 0.9458)
# Saving model (epoch =  324, loss = 0.9231)
# Saving model (epoch =  330, loss = 0.9213)
# Saving model (epoch =  332, loss = 0.9159)
# Saving model (epoch =  334, loss = 0.9103)
# Saving model (epoch =  338, loss = 0.9096)
# Saving model (epoch =  346, loss = 0.8985)
# Saving model (epoch =  355, loss = 0.8918)
# Saving model (epoch =  358, loss = 0.8845)
# Saving model (epoch =  362, loss = 0.8815)
# Saving model (epoch =  369, loss = 0.8693)
# Saving model (epoch =  380, loss = 0.8655)
# Saving model (epoch =  390, loss = 0.8608)
# Saving model (epoch =  405, loss = 0.8608)
# Saving model (epoch =  417, loss = 0.8509)
# Saving model (epoch =  435, loss = 0.8472)
# Saving model (epoch =  440, loss = 0.8448)
# Saving model (epoch =  445, loss = 0.8334)
# Saving model (epoch =  456, loss = 0.8184)
# Saving model (epoch =  543, loss = 0.8092)
# Saving model (epoch =  579, loss = 0.8089)
# Saving model (epoch =  661, loss = 0.8089)
# Saving model (epoch =  672, loss = 0.8083)
# Saving model (epoch =  675, loss = 0.8001)
# Saving model (epoch =  695, loss = 0.7922)
# Finished training after 896 epochs

# %%
plot_learning_curve(model_loss_record, title='deep model')

# %%
del model
model = NeuralNet(tr_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
plot_pred(dv_set, model, device)  # Show prediction on the validation set

# %% [markdown]
# # Testing

# %%
def save_pred(preds, file):
    ''' Save predictions to specified file '''
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(tt_set, model, device)  # predict COVID-19 cases with your model
save_pred(preds, 'pred.csv')         # save prediction file to pred.csv
# Out:
# Saving results to pred.csv

# %% [markdown]
# # Save File

# %%
from google.colab import files
files.download("pred.csv")

# %% [markdown]
# 1.   NN寬度層數
# 2.   Batch Normalization
# 3.   dropout 0.1 / 0.5
